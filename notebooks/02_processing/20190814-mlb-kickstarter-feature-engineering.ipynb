# %% [markdown]
# # FEATURE ENGINEERING: KICKSTARTER INTERMEDIATE DATA

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
kick_inter = pd.read_csv('../../data/02_intermediate/kick_inter.csv', 
                         parse_dates=['created_at', 'deadline', 
                                      'last_update_published_at', 
                                      'launched_at', 'state_changed_at'])
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (11,15,16,17,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cluster_feat_df = pd.read_pickle('../../data/03_processed/KNN_cluster_features_4.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-43e9838c5b86> in <module>
# ----> 1 cluster_feat_df = pd.read_pickle('../../data/03_processed/KNN_cluster_features_4.pkl')
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     173     return arr
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     147     # 1) try standard libary Pickle
#     148     # 2) try pickle_compat (older pandas version) to handle subclass changes
# --> 149     # 3) try pickle_compat with latin1 encoding
#     150
#     151     try:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in <lambda>(f)
#     173     return arr
#
# /anaconda3/lib/python3.7/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     210
#     211     try:
# --> 212         fh.seek(0)
#     213         if encoding is not None:
#     214             up = Unpickler(fh, encoding=encoding)
#
# /anaconda3/lib/python3.7/pickle.py in load(self)
#    1083                     raise EOFError
#    1084                 assert isinstance(key, bytes_types)
# -> 1085                 dispatch[key[0]](self)
#    1086         except _Stop as stopinst:
#    1087             return stopinst.value
#
# /anaconda3/lib/python3.7/pickle.py in load_stack_global(self)
#    1380         if type(name) is not str or type(module) is not str:
#    1381             raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1382         self.append(self.find_class(module, name))
#    1383     dispatch[STACK_GLOBAL[0]] = load_stack_global
#    1384
#
# /anaconda3/lib/python3.7/site-packages/pandas/compat/pickle_compat.py in find_class(self, module, name)
#     133     ("pandas.core.categorical", "Categorical"): ("pandas.core.arrays", "Categorical"),
#     134     # 19939, add timedeltaindex, float64index compat from 15998 move
# --> 135     ("pandas.tseries.tdi", "TimedeltaIndex"): (
#     136         "pandas.core.indexes.timedeltas",
#     137         "TimedeltaIndex",
#
# /anaconda3/lib/python3.7/pickle.py in find_class(self, module, name)
#    1421             elif module in _compat_pickle.IMPORT_MAPPING:
#    1422                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1423         __import__(module, level=0)
#    1424         if self.proto >= 4:
#    1425             return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'pandas.core.internals.managers'; 'pandas.core.internals' is not a package

# %% [markdown]
# ## Sources
#
# * average exchange rate over a decade - https://www.ofx.com/en-us/forex-news/historical-exchange-rates/yearly-average-rates/
# * world regions https://unstats.un.org/unsd/methodology/m49/
# * country codes https://laendercode.net/en/2-letter-list.html

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Restrict to Successful and Failed Campaings

# %%
kick_inter.state.value_counts()
# Out:
# successful    147268
# failed        129466
# live           38382
# canceled       16728
# suspended       1055
# Name: state, dtype: int64

# %%
kick_inter = kick_inter.loc[(kick_inter['state'] == 'successful')|(kick_inter['state'] == 'failed')]

# %% [markdown]
# ## Features List

# %% [markdown]
# **FEATURES TO CREATE (COLUMNS TO KEEP)**
# 1. blurb - blurb word count
# 1. launched_at & deadline (length of campaign)
# 1. currency
# 1. delta between created_at and launched_at
# 1. sub_category (159 values)
# 1. country_loc (210 values)
# 1. state_loc
# 1. goal in USD (goal * fx_rate)
# ---
# 1. **state [TARGET]**

# %%
kick_inter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276734 entries, 1 to 332898
# Data columns (total 42 columns):
# backers_count               276734 non-null int64
# blurb                       276732 non-null object
# converted_pledged_amount    164263 non-null float64
# country                     276734 non-null object
# created_at                  276734 non-null datetime64[ns]
# currency                    276734 non-null object
# currency_symbol             276734 non-null object
# currency_trailing_code      276734 non-null bool
# current_currency            164263 non-null object
# deadline                    276734 non-null datetime64[ns]
# disable_communication       276734 non-null bool
# friends                     50 non-null object
# fx_rate                     156437 non-null float64
# goal                        276734 non-null float64
# id                          276734 non-null int64
# is_backing                  50 non-null object
# is_starrable                172753 non-null object
# is_starred                  50 non-null object
# last_update_published_at    0 non-null datetime64[ns]
# launched_at                 276734 non-null datetime64[ns]
# name                        276733 non-null object
# permissions                 49 non-null object
# pledged                     276734 non-null float64
# slug                        276734 non-null object
# source_url                  239047 non-null object
# spotlight                   276734 non-null bool
# staff_pick                  276734 non-null bool
# state                       276734 non-null object
# state_changed_at            276734 non-null datetime64[ns]
# static_usd_rate             276734 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        276734 non-null object
# usd_pledged                 276734 non-null float64
# usd_type                    163570 non-null object
# sub_category                276734 non-null object
# overall_category            276734 non-null object
# city                        167436 non-null object
# country_loc                 275699 non-null object
# state_loc                   275642 non-null object
# creator_name                276708 non-null object
# creator_slug                85873 non-null object
# dtypes: bool(4), datetime64[ns](5), float64(8), int64(2), object(23)
# memory usage: 83.4+ MB

# %%
kick_inter.head(3)
# Out:
#    backers_count                                              blurb  \
# 1            568  for Tabletop Role Playing Games like Dungeons ...
# 3             80  We have a new album that we are ready to relea...
# 6             23  Alluvia Magazine is a print publication and cr...
#
#    converted_pledged_amount country          created_at currency  \
# 1                   18969.0      US 2019-06-02 21:06:55      USD
# 3                    3691.0      US 2019-06-27 18:36:40      USD
# 6                     886.0      US 2019-07-01 22:55:44      USD
#
#   currency_symbol  currency_trailing_code current_currency  \
# 1               $                    True              USD
# 3               $                    True              USD
# 6               $                    True              USD
#
#              deadline  disable_communication friends  fx_rate    goal  \
# 1 2019-07-18 03:55:00                  False     NaN      1.0  5000.0
# 3 2019-07-18 03:30:00                  False     NaN      1.0  3500.0
# 6 2019-07-18 03:20:41                  False     NaN      1.0   500.0
#
#            id is_backing is_starrable is_starred last_update_published_at  \
# 1  1175125319        NaN        False        NaN                      NaT
# 3   920424993        NaN        False        NaN                      NaT
# 6  1253520992        NaN        False        NaN                      NaT
#
#           launched_at                                               name  \
# 1 2019-06-16 02:20:41  RPG Minimalist Creature Dice & Status / Condit...
# 3 2019-06-29 04:17:17      Drank The Gold's new album: Sipped The Silver
# 6 2019-07-03 03:20:41  Alluvia Magazine: Amplifying POC environmental...
#
#   permissions  pledged                                               slug  \
# 1         NaN  18969.0  rpg-minimalist-creature-dice-and-status-condit...
# 3         NaN   3691.0        drank-the-golds-new-album-sipped-the-silver
# 6         NaN    886.0  alluvia-magazine-amplifying-poc-environmental-art
#
#                                           source_url  spotlight  staff_pick  \
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...       True        True
# 6  https://www.kickstarter.com/discover/categorie...       True        True
#
#         state    state_changed_at  static_usd_rate  unread_messages_count  \
# 1  successful 2019-07-18 03:55:01              1.0                    NaN
# 3  successful 2019-07-18 03:30:00              1.0                    NaN
# 6  successful 2019-07-18 03:20:41              1.0                    NaN
#
#    unseen_activity_count                                               urls  \
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 3                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 6                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#    usd_pledged  usd_type    sub_category      overall_category  \
# 1      18969.0  domestic  Tabletop Games  games/tabletop games
# 3       3691.0  domestic           Music                 music
# 6        886.0  domestic           Zines      publishing/zines
#
#                city country_loc state_loc     creator_name  creator_slug
# 1           Holland          US        MI  quEmpire Gaming      quempire
# 3  Saratoga Springs          US        NY   Drank The Gold  drankthegold
# 6           Oakland          US        CA  Zahira Chaudhry           NaN

# %%
kick_inter.columns
# Out:
# Index(['backers_count', 'blurb', 'converted_pledged_amount', 'country',
#        'created_at', 'currency', 'currency_symbol', 'currency_trailing_code',
#        'current_currency', 'deadline', 'disable_communication', 'friends',
#        'fx_rate', 'goal', 'id', 'is_backing', 'is_starrable', 'is_starred',
#        'last_update_published_at', 'launched_at', 'name', 'permissions',
#        'pledged', 'slug', 'source_url', 'spotlight', 'staff_pick', 'state',
#        'state_changed_at', 'static_usd_rate', 'unread_messages_count',
#        'unseen_activity_count', 'urls', 'usd_pledged', 'usd_type',
#        'sub_category', 'overall_category', 'city', 'country_loc', 'state_loc',
#        'creator_name', 'creator_slug'],
#       dtype='object')

# %%
kick_inter.drop(columns=['backers_count', 'converted_pledged_amount', 'country',
                         'currency_symbol', 'currency_trailing_code', 'current_currency', 
                         'friends', 'is_backing', 'is_starrable', 'is_starred',
                         'last_update_published_at', 'permissions', 'pledged', 
                         'slug', 'source_url', 'spotlight', 'staff_pick', 'static_usd_rate', 
                         'unread_messages_count','unseen_activity_count', 'urls', 'usd_pledged', 
                         'usd_type', 'overall_category', 'creator_name', 'creator_slug', 'disable_communication'], 
                inplace=True)

# %% [markdown]
# ### BLURB WORD COUNT

# %%
kick_inter['blurb_word_count'] = kick_inter.blurb.str.split().str.len()

# %%
kick_inter.drop('blurb', axis=1, inplace=True)

# %% [markdown]
# ### LENGTH OF CAMPAIGN

# %%
kick_inter['campaign_length'] = (kick_inter['deadline'] - kick_inter['launched_at']).dt.days

# %% [markdown]
# ### DELTA BETWEEN CREATED AT AND LAUNCHED AT

# %%
kick_inter['delta_created_launched'] = (kick_inter['launched_at'] - kick_inter['created_at']).dt.days

# %% [markdown]
# ### GOAL IN USD

# %% [markdown]
# Time Period

# %%
kick_inter.created_at.min()
# Out:
# Timestamp('2009-04-21 17:35:35')

# %%
kick_inter.created_at.max()
# Out:
# Timestamp('2019-07-10 23:26:41')

# %% [markdown]
# ### CONVERT GOAL TO USD

# 72     2019-07-17 19:01:58           Musical          New York          US
# 76     2019-07-17 18:59:14      Illustration           Phoenix          US
# 77     2019-07-17 18:55:06      Performances       Los Angeles          US
# 82     2019-07-17 18:27:46               Art            Denver          US
# ...                    ...               ...               ...         ...
# 332867 2009-07-01 04:00:40            Shorts               NaN         NaN
# 332868 2009-06-30 09:45:21           Puzzles               NaN         NaN
# 332869 2009-06-24 22:30:31       Periodicals          New York          US
# 332870 2009-06-21 04:00:29       Documentary         Ypsilanti          US
# 332871 2009-06-21 00:45:20       Documentary         Claremont          US
# 332872 2009-06-20 20:15:20    Narrative Film               NaN         NaN
# 332873 2009-06-17 04:00:31       Photography               NaN         NaN
# 332874 2009-06-16 06:45:17            Crafts          Portland          US
# 332875 2009-06-15 19:00:31          Software          New York          US
# 332876 2009-06-15 05:15:19    Tabletop Games               NaN          US
# 332877 2009-06-15 04:00:29            Comics         Cleveland          US
# 332878 2009-06-15 04:00:28      Illustration               NaN         NaN
# 332879 2009-06-15 00:45:21        Nonfiction        Washington          US
# 332880 2009-06-14 02:30:32          Painting               NaN         NaN
# 332881 2009-06-12 19:00:32        Journalism           Chicago          US
# 332882 2009-06-06 05:00:22          Painting          New York          US
# 332883 2009-06-05 22:45:25      Film & Video            Muncie          US
# 332884 2009-06-05 07:00:24  Electronic Music       New Orleans          US
# 332885 2009-06-05 04:00:25           Theater          Brooklyn          US
# 332886 2009-06-04 04:00:22        Nonfiction           Atlanta          US
# 332887 2009-06-02 05:45:19      Film & Video       Los Angeles          US
# 332888 2009-06-01 16:00:28          Software               NaN         NaN
# 332889 2009-06-01 16:00:21           Theater             Floyd          US
# 332890 2009-06-01 00:30:19       Documentary               NaN          US
# 332891 2009-05-31 11:45:17         Sculpture        Bronxville          US
# 332892 2009-05-29 00:15:21           Fiction               NaN         NaN
# 332893 2009-05-22 21:30:18      Illustration        Bronxville          US
# 332894 2009-05-16 10:00:25        Journalism          New York          US
# 332895 2009-05-16 00:00:18              Rock               NaN          US
# 332898 2009-05-03 07:00:17      Illustration               NaN         NaN
#
#               state_loc  blurb_word_count  campaign_length  \
# 1                    MI               9.0               32
# 3                    NY              14.0               18
# 6                    CA              17.0               15
# 7                    CA              12.0               30
# 8                    MA              19.0               30
# 11                   ME              16.0               30
# 13                   CA              26.0               29
# 14                   WI               5.0               30
# 17                   VA              14.0               14
# 18                   PA              20.0               30
# 22            Andalusia              16.0               42
# 24                   WA              13.0               19
# 25        Ile-de-France              21.0               23
# 26                   NY              18.0               27
# 35                  NSW              18.0               48
# 38                   CT              14.0               30
# 41                   OR              22.0               43
# 46                   AR               3.0               60
# 49                   WI              23.0               30
# 51      Vastra Gotaland              10.0               21
# 53                   NY              20.0               30
# 54                   NY               6.0               30
# 56                   MD              17.0               30
# 61                   CA              11.0                7
# 70                   CA               3.0               30
# 71                   NY              25.0               60
# 72                   NY              13.0               30
# 76                   AZ              12.0               12
# 77                   CA              17.0               28
# 82                   CO              21.0               30
# ...                 ...               ...              ...
# 332867              NaN              28.0               32
# 332868              NaN              24.0               61
# 332869               NY              22.0               13
# 332870               MI              18.0               33
# 332871               CA              22.0               21
# 332872              NaN              23.0               36
# 332873              NaN              30.0               48
# 332874               OR              26.0               36
# 332875               NY              22.0               46
# 332876               NY              28.0               30
# 332877               OH              10.0               16
# 332878              NaN              30.0               29
# 332879               DC              23.0               34
# 332880              NaN              25.0               30
# 332881               IL              26.0                3
# 332882               NY              20.0               32
# 332883               IN              22.0               36
# 332884               LA              22.0               34
# 332885               NY              23.0               35
# 332886               GA              21.0               30
# 332887               CA              15.0               29
# 332888              NaN              22.0               24
# 332889               VA              24.0               31
# 332890               NY              19.0               27
# 332891               NY              18.0               29
# 332892              NaN              24.0               29
# 332893               NY              22.0                9
# 332894               NY              24.0               17
# 332895               IL              25.0               16
# 332898              NaN              26.0                8
#
#         delta_created_launched
# 1                           13
# 3                            1
# 6                            1
# 7                            6
# 8                            0
# 11                          13
# 13                           0
# 14                         125
# 17                          12
# 18                           1
# 22                          97
# 24                           3
# 25                           2
# 26                           3
# 35                          31
# 38                          40
# 41                           7
# 46                           0
# 49                          10
# 51                           3
# 53                           9
# 54                         408
# 56                          33
# 61                           2
# 70                          14
# 71                          67
# 72                          11
# 76                          10
# 77                          11
# 82                           8
# ...                        ...
# 332867                       3
# 332868                       0
# 332869                       1
# 332870                       0
# 332871                       0
# 332872                       3
# 332873                       0
# 332874                       0
# 332875                       0
# 332876                       0
# 332877                       1
# 332878                       0
# 332879                       2
# 332880                       0
# 332881                       0
# 332882                       0
# 332883                       0
# 332884                       9
# 332885                       6
# 332886                       0
# 332887                       0
# 332888                       0
# 332889                       1
# 332890                       4
# 332891                       0
# 332892                       0
# 332893                       0
# 332894                       1
# 332895                       0
# 332898                       0
#
# [276734 rows x 17 columns]

# %%
bool_series = pd.isnull(kick_inter["fx_rate"])  
kick_inter[bool_series].currency.value_counts()
# Out:
# USD    95396
# GBP    10819
# EUR     4847
# CAD     4616
# AUD     2470
# SEK      539
# NZD      462
# DKK      341
# NOK      228
# MXN      209
# CHF      194
# SGD      103
# HKD       73
# Name: currency, dtype: int64

# %% [markdown]
# Let's fill in the null fx columns with the average exchange rate from the last decade. Our dataset is over a decade so this should work just fine.

# %%
avg_fx_rate_10yr = {
    'EUR': 1.231885, 
    'MXN': 0.068639, 
    'USD': 1.000000, 
    'GBP': 1.473741, 
    'CAD': 0.869234, 
    'SEK': 0.131576, 
    'DKK': 0.165301, 
    'HKD': 0.128529, 
    'NOK': 0.14488,
    'AUD': 0.857369, 
    'SGD': 0.757244, 
    'CHF': 1.043232, 
    'NZD': 0.744532
}
currency = ['EUR', 'MXN', 'USD', 'GBP', 'CAD', 
            'SEK', 'DKK', 'HKD', 'NOK', 'AUD', 
            'SGD', 'CHF', 'NZD']

for cur in currency:
    null_exRatesEUR = ((kick_inter.fx_rate.isnull()) & (kick_inter.currency==cur))
    kick_inter.loc[null_exRatesEUR, 'fx_rate']=avg_fx_rate_10yr[cur]

# %%
kick_inter['goal_usd'] = kick_inter.goal * kick_inter.fx_rate

# %%
kick_inter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276734 entries, 1 to 332898
# Data columns (total 18 columns):
# created_at                276734 non-null datetime64[ns]
# currency                  276734 non-null object
# deadline                  276734 non-null datetime64[ns]
# fx_rate                   276734 non-null float64
# goal                      276734 non-null float64
# id                        276734 non-null int64
# launched_at               276734 non-null datetime64[ns]
# name                      276733 non-null object
# state                     276734 non-null object
# state_changed_at          276734 non-null datetime64[ns]
# sub_category              276734 non-null object
# city                      167436 non-null object
# country_loc               275699 non-null object
# state_loc                 275642 non-null object
# blurb_word_count          276732 non-null float64
# campaign_length           276734 non-null int64
# delta_created_launched    276734 non-null int64
# goal_usd                  276734 non-null float64
# dtypes: datetime64[ns](4), float64(4), int64(3), object(7)
# memory usage: 40.1+ MB

# %%
kick_inter.drop(columns=['created_at', 'deadline', 'fx_rate', 'launched_at', 
                         'state_changed_at', 'city', 'state_loc', 'name'], 
                inplace=True)

# %%
kick_inter.rename({'goal':'goal_original', 'state':'target', 
                   'sub_category': 'category', 'country_loc':'country'}, 
                  axis=1, inplace=True)

# %% [markdown]
# ### Drop Duplicated ID

# %% [markdown]
# we know from our analysis that there are some IDs with several different names. When we dive in a little further it becomes clear that these are just examples of people changing the name of their campaigns lightly after launching. we will sort and in decending order by created and keep the first date.

# %%
counts = kick_inter['id'].value_counts()
kick_inter[kick_inter['id'].isin(counts.index[counts == 2])]
# Out:
#        currency  goal_original          id      target            category  \
# 19053       USD         8000.0   965707427  successful        Architecture
# 19054       USD         8000.0   965707427  successful        Architecture
# 23024       CAD          550.0   790705723  successful         Comic Books
# 23025       CAD          550.0   790705723  successful         Comic Books
# 29251       EUR        25000.0  1072129063  successful             Apparel
# 29252       EUR        25000.0  1072129063  successful             Apparel
# 48516       USD         5000.0   387484708  successful      Product Design
# 48517       USD         5000.0   387484708  successful      Product Design
# 57743       EUR        25000.0  1409012589  successful             Apparel
# 57744       EUR        25000.0  1409012589  successful             Apparel
# 67227       USD         2500.0  1135601496      failed      Graphic Design
# 67228       USD         2500.0  1135601496      failed      Graphic Design
# 70455       USD        30000.0  1003111955  successful          Technology
# 70456       USD        30000.0  1003111955  successful          Technology
# 72547       EUR        75000.0   476220148  successful            Hardware
# 72548       EUR        75000.0   476220148  successful            Hardware
# 77148       USD        30000.0  2104907208  successful            Hardware
# 77149       USD        30000.0  2104907208  successful            Hardware
# 81649       USD         7000.0   374473984  successful         Accessories
# 81650       USD         7000.0   374473984  successful         Accessories
# 96676       USD          500.0  1436747808      failed             Hip-Hop
# 96677       USD          500.0  1436747808      failed             Hip-Hop
# 98402       USD        50000.0   405575828  successful    Camera Equipment
# 98404       USD        50000.0   405575828  successful    Camera Equipment
# 101728      GBP         6000.0  1644028140  successful             Gadgets
# 101729      GBP         6000.0  1644028140  successful             Gadgets
# 102067      EUR         3000.0  1319073749  successful         Comic Books
# 102068      EUR         3000.0  1319073749  successful         Comic Books
# 102240      EUR        25000.0   249618800  successful             Apparel
# 102241      EUR        25000.0   249618800  successful             Apparel
# ...         ...            ...         ...         ...                 ...
# 195181      USD         4444.0  2054476698  successful          Indie Rock
# 195182      USD         4444.0  2054476698  successful          Indie Rock
# 201952      USD        50000.0   255263163  successful  Interactive Design
# 201953      USD        50000.0   255263163  successful  Interactive Design
# 206986      GBP          500.0    96887393  successful      Conceptual Art
# 206987      GBP          500.0    96887393  successful      Conceptual Art
# 207889      USD          350.0   162212619  successful            Fine Art
# 207890      USD          350.0   162212619  successful            Fine Art
# 225248      USD         3500.0  2034649639      failed             Hip-Hop
# 225249      USD         3500.0  2034649639      failed             Hip-Hop
# 240680      GBP         1250.0   503000061      failed         Mixed Media
# 240681      GBP         1250.0   503000061      failed         Mixed Media
# 251971      GBP          500.0   273639254  successful              Shorts
# 251973      GBP          500.0   273639254  successful              Shorts
# 257824      GBP         2375.0  1210399268      failed          Public Art
# 257825      GBP         2375.0  1210399268      failed          Public Art
# 260041      USD         4500.0   237938270  successful      Product Design
# 260042      USD         4500.0   237938270  successful      Product Design
# 269278      USD         1000.0  1849040930      failed         Mixed Media
# 269279      USD         1000.0  1849040930      failed         Mixed Media
# 281046      USD         6000.0   990649488  successful          Indie Rock
# 281047      USD         6000.0   990649488  successful          Indie Rock
# 286488      USD        25000.0  1805635015  successful                Food
# 286489      USD        25000.0  1805635015  successful                Food
# 307196      USD         3500.0   394648626  successful            Software
# 307197      USD         3500.0   394648626  successful            Software
# 324528      USD         7750.0  2055334986  successful              Shorts
# 324532      USD         7750.0  2055334986  successful              Shorts
# 326819      USD         4000.0  2047023433  successful        Film & Video
# 326820      USD         4000.0  2047023433  successful        Film & Video
#
#        country  blurb_word_count  campaign_length  delta_created_launched  \
# 19053       US              14.0               15                       8
# 19054       US              13.0               15                       8
# 23024       CA              24.0               14                      60
# 23025       CA              24.0               14                      60
# 29251       NL              17.0               33                       1
# 29252       NL              17.0               33                       1
# 48516       US              20.0               60                       6
# 48517       US              20.0               60                       6
# 57743       NL              18.0               43                      54
# 57744       NL              18.0               43                      54
# 67227       US              21.0               15                     157
# 67228       US              21.0               15                     157
# 70455       US              20.0               30                      47
# 70456       US              20.0               30                      47
# 72547       DE              18.0               30                      83
# 72548       DE              18.0               30                      83
# 77148       US              23.0               45                     610
# 77149       US              23.0               45                     610
# 81649       US              25.0               30                     365
# 81650       US              25.0               30                     365
# 96676       US              22.0               30                      16
# 96677       US              22.0               30                      16
# 98402       US              20.0               30                      67
# 98404       US              20.0               30                      67
# 101728      GB              24.0               30                      18
# 101729      GB              24.0               30                      18
# 102067      NL              19.0               30                       9
# 102068      NL              19.0               30                       9
# 102240      NL              19.0               39                      52
# 102241      NL              19.0               39                      52
# ...        ...               ...              ...                     ...
# 195181      US              19.0               30                      10
# 195182      US              19.0               30                      10
# 201952      US               3.0               32                      17
# 201953      US              18.0               32                      17
# 206986      HU              10.0               29                      58
# 206987      HU              10.0               29                      58
# 207889      US              16.0               30                       0
# 207890      US              16.0               30                       0
# 225248      US              18.0               21                      29
# 225249      US              18.0               21                      29
# 240680      GB              19.0               21                      14
# 240681      GB              19.0               21                      14
# 251971      GB              22.0               24                       5
# 251973      GB              22.0               24                       5
# 257824      GB              20.0               30                       6
# 257825      GB              20.0               30                       6
# 260041      US              17.0               32                      23
# 260042      US              17.0               32                      23
# 269278      US              25.0               60                      10
# 269279      US              25.0               60                      10
# 281046      US              19.0               35                      59
# 281047      US              19.0               35                      59
# 286488      US              23.0               25                      11
# 286489      US              23.0               25                      11
# 307196      US              26.0               30                      12
# 307197      US              26.0               30                      12
# 324528      US              19.0               44                       0
# 324532      US              19.0               44                       0
# 326819      US              22.0               30                      18
# 326820      US              22.0               30                      18
#
#             goal_usd
# 19053    8000.000000
# 19054    8000.000000
# 23024     413.173475
# 23025     415.370835
# 29251   28021.942250
# 29252   28098.633000
# 48516    6641.395000
# 48517    5000.000000
# 57743   28526.080250
# 57744   28098.633000
# 67227    2500.000000
# 67228    2500.000000
# 70455   30000.000000
# 70456   30000.000000
# 72547   84700.589250
# 72548   92763.460500
# 77148   30000.000000
# 77149   30000.000000
# 81649    7000.000000
# 81650    7000.000000
# 96676     500.000000
# 96677     500.000000
# 98402   50000.000000
# 98404   50000.000000
# 101728   8842.446000
# 101729   8842.446000
# 102067   3736.990590
# 102068   3713.923860
# 102240  30797.125000
# 102241  28098.633000
# ...              ...
# 195181   4444.000000
# 195182   4444.000000
# 201952  50000.000000
# 201953  50000.000000
# 206986    709.161515
# 206987    736.870500
# 207889    350.000000
# 207890    350.000000
# 225248   3500.000000
# 225249   3500.000000
# 240680   1842.176250
# 240681   1632.213900
# 251971    634.400225
# 251973    736.870500
# 257824   3500.134875
# 257825   3111.130917
# 260041   4500.000000
# 260042   4500.000000
# 269278   1000.000000
# 269279   1000.000000
# 281046   6000.000000
# 281047   6000.000000
# 286488  25000.000000
# 286489  25000.000000
# 307196   3500.000000
# 307197   3500.000000
# 324528   7750.000000
# 324532   7750.000000
# 326819   4000.000000
# 326820   4000.000000
#
# [110 rows x 10 columns]

# %%
kick_inter.drop_duplicates(subset=['id'], keep='first', inplace=True)

# %%
len(kick_inter)
# Out:
# 276679

# %%
kick_inter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276679 entries, 1 to 332898
# Data columns (total 10 columns):
# currency                  276679 non-null object
# goal_original             276679 non-null float64
# id                        276679 non-null int64
# target                    276679 non-null object
# category                  276679 non-null object
# country                   275644 non-null object
# blurb_word_count          276677 non-null float64
# campaign_length           276679 non-null int64
# delta_created_launched    276679 non-null int64
# goal_usd                  276679 non-null float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 23.2+ MB

# %%
kick_inter.head()
# Out:
#   currency  goal_original          id      target        category country  \
# 1      USD         5000.0  1175125319  successful  Tabletop Games      US
# 3      USD         3500.0   920424993  successful           Music      US
# 6      USD          500.0  1253520992  successful           Zines      US
# 7      USD         6800.0   335137457  successful  Graphic Novels      US
# 8      USD          600.0    58084093  successful     Mixed Media      US
#
#    blurb_word_count  campaign_length  delta_created_launched  goal_usd
# 1               9.0               32                      13    5000.0
# 3              14.0               18                       1    3500.0
# 6              17.0               15                       1     500.0
# 7              12.0               30                       6    6800.0
# 8              19.0               30                       0     600.0

# %%
kick_inter['successful_dummy'] = pd.get_dummies(kick_inter['target'], drop_first=True)

# %%
# we no longer need our ID column anymore
kick_inter.drop(columns=['target'], inplace=True)

# %% [markdown]
# We also need to erase our ID column. This doesn't add any information

# %% [markdown]
# OK, let's take one last look out our dataset to make sure that we don't have anything else to get rid of.

# %%
kick_inter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276679 entries, 1 to 332898
# Data columns (total 10 columns):
# currency                  276679 non-null object
# goal_original             276679 non-null float64
# id                        276679 non-null int64
# category                  276679 non-null object
# country                   275644 non-null object
# blurb_word_count          276677 non-null float64
# campaign_length           276679 non-null int64
# delta_created_launched    276679 non-null int64
# goal_usd                  276679 non-null float64
# successful_dummy          276679 non-null uint8
# dtypes: float64(3), int64(3), object(3), uint8(1)
# memory usage: 21.4+ MB

# %%
kick_inter.country.isnull().sum()/len(kick_inter)
# Out:
# 0.0037407970969968807

# %%
kick_inter.dropna(inplace=True)

# %% [markdown]
# ### Let's combine the location column

# %%
# build a world regions dictionary 
world_regions = {
    'Northern America': ['US', 'CA', 'MX', 'GL', 'BM'], 
    'Northern Africa':['MA', 'TN', 'EG', 'LY', 'DZ', 'SD'], 
    'Eastern Africa':['KE', 'MG', 'MW', 'ET', 'UG', 'TZ', 'RW', 'MU', 'ZW', 'SO', 'SC', 'MZ', 'ZM', 'DJ', 
                      'SS'], 
    'Middle Africa':['CM', 'TD', 'CG', 'CD', 'GA', 'GQ', 'CF'], 
    'Southern Africa':['ZA', 'BW', 'SZ', 'LS'], 
    'Western Africa':['GH', 'NG', 'LR', 'SN', 'ML', 'SL', 'NE', 'BF', 'GN', 'GM', 'CI', 'CV', 'MR', 'BJ'], 
    'Caribbean':['HT', 'TT', 'PR', 'DO', 'JM', 'BS', 'CU', 'KY', 'CW', 'GP', 'SX', 'VI', 'BB', 
                 'AG', 'DM', 'LC', 'VC', 'TC', 'KN', 'GD'], 
    'Central America':['GT', 'SV','BZ', 'PA', 'HN', 'CR', 'NI'], 
    'South America':['CO', 'PE', 'VE', 'EC', 'AR', 'BR', 'CL', 'BO', 'SR', 'UY', 'PY', 'GY'], 
    'Central Asia':['KG', 'KZ', 'TJ'], 
    'Eastern Asia':['HK', 'JP', 'CN', 'MN', 'KR', 'MQ', 'TW', 'KP', 'MO'], 
    'South-eastern Asia':['ID', 'SG', 'VN', 'MY', 'TH', 'KH', 'PH', 'MM', 'LA', 'TL'], 
    'Southern Asia':['BD', 'IN', 'LK', 'NP', 'AF', 'PK', 'BT', 'IR', 'MV'], 
    'Western Asia':['IL', 'JO', 'AM', 'LB', 'AE', 'CY', 'PS', 'GE', 'YE', 'IQ', 'KW', 'AZ', 'SA', 
                    'SY', 'QA', 'BH', 'TR'], 
    'Eastern Europe':['PL', 'RO', 'UA', 'MD', 'HU', 'CZ', 'RU', 'BG', 'SK', 'BY', 'FO'], 
    'Northern Europe':['SE', 'GB', 'NO', 'IE', 'DK', 'FI', 'LT', 'IS', 'EE', 'SJ', 'LV', 'AX'], 
    'Southern Europe': ['ES', 'IT', 'HR', 'RS', 'PT', 'SI', 'GR', 'MT', 'BA', 'MK', 'XK', 'GI', 
                        'VA', 'MC', 'AL', 'ME'],
    'Western Europe':['FR', 'CH', 'DE', 'BE', 'NL', 'LU', 'AT', 'MC'], 
    'Australia and New Zealand':['AU', 'NZ'], 
    'Melanesia':['VU', 'PG', 'FJ', 'NC'], 
    'Micronesia':['FM', 'GU', 'KI'], 
    'Polynesia':['WS', 'TO', 'CK', 'PF', 'PN'], 
    'Antarctica': ['AQ']
}

# %%
# flip the dictionary to make each individual value in the value list a new key. 
countries_regions = {}
for key, val in world_regions.items():
    for i in range(len(val)):
        countries_regions[val[i]] = key

# %%
# let's make a for loop to assign the correct region to the correct country in our dataframe. 
countries = ['US', 'ES', 'FR', 'AU', 'SE', 'CH', 'CA', 'GB', 'IT', 'NO', 'HK',
       'KE', 'MX', 'IE', 'JP', 'DE', 'BE', 'NZ', 'NL', 'CN', 'CO', 'GT',
       'HR', 'PL', 'DK', 'MN', 'ID', 'LU', 'FI', 'KR', 'SG', 'GH', 'HT',
       'BD', 'RS', 'AT', 'TT', 'NG', 'PE', 'SV', 'PT', 'ZA', 'MG', 'VN',
       'MQ', 'IL', 'PR', 'RO', 'TW', 'UA', 'MD', 'JO', 'TR', 'CM', 'SI',
       'IN', 'VE', 'AM', 'EC', 'HU', 'AR', 'LK', 'MA', 'LB', 'BR', 'CL',
       'CZ', 'BO', 'GL', 'MY', 'TH', 'GR', 'MW', 'BZ', 'RU', 'AE', 'KH',
       'DO', 'CY', 'ET', 'UG', 'MT', 'PA', 'HN', 'BG', 'PH', 'LR', 'CR',
       'LT', 'TZ', 'SK', 'TN', 'WS', 'BA', 'IS', 'PS', 'BY', 'SN', 'MK',
       'KG', 'ML', 'SR', 'VU', 'PG', 'EE', 'NP', 'UY', 'GE', 'TD', 'AQ',
       'RW', 'CG', 'FM', 'SL', 'SJ', 'BW', 'TO', 'GU', 'YE', 'MM', 'AF',
       'CK', 'JM', 'CD', 'KZ', 'EG', 'MU', 'ZW', 'FJ', 'XK', 'PY', 'BS',
       'PK', 'CU', 'NI', 'KY', 'LV', 'CW', 'NE', 'GI', 'BF', 'SO', 'LY',
       'GP', 'SC', 'TJ', 'GN', 'GM', 'SX', 'MZ', 'VA', 'IQ', 'BT', 'VI',
       'KW', 'SZ', 'MC', 'CI', 'LA', 'AL', 'GY', 'BB', 'ZM', 'AG', 'DJ',
       'IR', 'DM', 'CV', 'NC', 'DZ', 'KP', 'FO', 'LS', 'TL', 'KI', 'PF',
       'MR', 'LC', 'VC', 'AX', 'MO', 'AZ', 'SA', 'SY', 'PN', 'GA', 'GQ',
       'TC', 'KN', 'QA', 'BJ', 'MV', 'SS', 'SD', 'ME', 'BH', 'GD', 'CF',
       'BM']

for country in countries:
    kick_inter.loc[kick_inter['country']==country, 'world_regions']=countries_regions[country]

# %%
kick_inter
# Out:
#        currency  goal_original          id          category country  \
# 1           USD         5000.0  1175125319    Tabletop Games      US
# 3           USD         3500.0   920424993             Music      US
# 6           USD          500.0  1253520992             Zines      US
# 7           USD         6800.0   335137457    Graphic Novels      US
# 8           USD          600.0    58084093       Mixed Media      US
# 11          USD         5000.0  1117025715             Faith      US
# 13          USD          100.0   750949205    Narrative Film      US
# 14          USD         3500.0  1852138418            Design      US
# 17          USD         1000.0    46781774            Comics      US
# 18          USD          825.0  1598130539               Art      US
# 22          EUR       100000.0  1967719903          Software      ES
# 24          USD         3600.0  1445139804      Illustration      US
# 25          USD        15000.0   819291103    Tabletop Games      FR
# 26          USD         2000.0   887535033            Comics      US
# 35          AUD         5000.0   824115050    Product Design      AU
# 38          USD          500.0  2003128160       Digital Art      US
# 41          USD         6000.0    81159415        Nonfiction      US
# 46          USD         3500.0  1428903281       Young Adult      US
# 49          USD       100000.0  1110622119            Spaces      US
# 51          SEK       173000.0  1133160588   Gaming Hardware      SE
# 53          USD         7000.0   541634674         Webseries      US
# 54          USD         2500.0  1887640533       Accessories      US
# 56          USD         5000.0  1940089951       Video Games      US
# 61          USD         1500.0   980834458    Tabletop Games      US
# 70          USD          100.0  2021908288  Electronic Music      US
# 71          USD        30000.0  1876685009           Fantasy      US
# 72          USD         3200.0   924121911           Musical      US
# 76          USD          300.0  1833748911      Illustration      US
# 77          USD        15000.0   152050702      Performances      US
# 82          USD         3000.0   875922255               Art      US
# ...         ...            ...         ...               ...     ...
# 332850      USD          300.0  1573743464         Webseries      LB
# 332851      USD         3500.0   585544140        Indie Rock      US
# 332852      USD          640.0  1167151653    Graphic Design      US
# 332854      USD         3000.0   737331933       Video Games      US
# 332855      USD         3000.0   202333685       Photography      US
# 332856      USD         3000.0  1971808443       Photography      US
# 332858      USD          500.0   530647695             Music      US
# 332859      USD          500.0  1864211900              Food      TH
# 332860      USD          100.0   353710709          Painting      US
# 332869      USD          600.0  2082649258       Periodicals      US
# 332870      USD         1000.0   827245452       Documentary      US
# 332871      USD         1250.0  1125367305       Documentary      US
# 332874      USD          200.0  1130941392            Crafts      US
# 332875      USD          500.0   177921463          Software      US
# 332876      USD         1500.0  1839304671    Tabletop Games      US
# 332877      USD           60.0  1451130282            Comics      US
# 332879      USD        30000.0  1301564845        Nonfiction      US
# 332881      USD          900.0   598270843        Journalism      US
# 332882      USD         5000.0   772300929          Painting      US
# 332883      USD          500.0  1099226462      Film & Video      US
# 332884      USD         4000.0   405307432  Electronic Music      US
# 332885      USD         6000.0  1304906577           Theater      US
# 332886      USD         1000.0  1316334968        Nonfiction      US
# 332887      USD          200.0  2096107260      Film & Video      US
# 332889      USD          500.0   901991585           Theater      US
# 332890      USD          700.0  1100844465       Documentary      US
# 332891      USD         2000.0  1578671837         Sculpture      US
# 332893      USD           30.0   199916122      Illustration      US
# 332894      USD         3000.0  2089078683        Journalism      US
# 332895      USD          300.0   813230527              Rock      US
#
#         blurb_word_count  campaign_length  delta_created_launched  \
# 1                    9.0               32                      13
# 3                   14.0               18                       1
# 6                   17.0               15                       1
# 7                   12.0               30                       6
# 8                   19.0               30                       0
# 11                  16.0               30                      13
# 13                  26.0               29                       0
# 14                   5.0               30                     125
# 17                  14.0               14                      12
# 18                  20.0               30                       1
# 22                  16.0               42                      97
# 24                  13.0               19                       3
# 25                  21.0               23                       2
# 26                  18.0               27                       3
# 35                  18.0               48                      31
# 38                  14.0               30                      40
# 41                  22.0               43                       7
# 46                   3.0               60                       0
# 49                  23.0               30                      10
# 51                  10.0               21                       3
# 53                  20.0               30                       9
# 54                   6.0               30                     408
# 56                  17.0               30                      33
# 61                  11.0                7                       2
# 70                   3.0               30                      14
# 71                  25.0               60                      67
# 72                  13.0               30                      11
# 76                  12.0               12                      10
# 77                  17.0               28                      11
# 82                  21.0               30                       8
# ...                  ...              ...                     ...
# 332850              22.0               22                       2
# 332851              25.0               61                       0
# 332852              19.0               65                       0
# 332854              24.0               30                       0
