# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

src_dir = os.path.join(os.getcwd(), '..', '..', 'src')
sys.path.append(src_dir)
pd.set_option('display.max_columns', None)

# %%
map_data = pd.read_pickle('../../data/02_intermediate/kick_World_map.pkl')

# %%
map_data.head()
# Out:
#    backers_count    goal          id                               name state  \
# 0              1  1500.0   654869661  Josiah Gennell: Creating First EP  live
# 1              0  5000.0  1290757180  Giuliano Clothing: Modern Fashion  live
# 2              1  4000.0  1747360837                  CincyPet Magazine  live
# 3              4   370.0   592255111          Bad-ass Women Enamel Pins  live
# 4              4   370.0   592255111          Bad-ass Women Enamel Pins  live
#
#                                                 urls sub_category  \
# 0  {"web":{"project":"https://www.kickstarter.com...   Indie Rock
# 1  {"web":{"project":"https://www.kickstarter.com...      Fashion
# 2  {"web":{"project":"https://www.kickstarter.com...  Periodicals
# 3  {"web":{"project":"https://www.kickstarter.com...          Art
# 4  {"web":{"project":"https://www.kickstarter.com...          Art
#
#          overall_category        city country_loc state_loc      lat      lng
# 0        music/indie rock     Methuen          US        MA  42.7340 -71.1889
# 1                 fashion     Toronto          CA        ON  43.7000 -79.4200
# 2  publishing/periodicals  Cincinnati          US        OH  39.1412 -84.5059
# 3                     art      Dallas          US        TX  32.7937 -96.7662
# 4                     art      Dallas          US        TX  32.7937 -96.7662

# %%
locations = list(zip(map_data.lat, map_data.lng))
popup_content = list(zip(map_data.name, map_data.backers_count, map_data.goal, map_data.sub_category))
popups = ['<center> {} <br>  <b>Category:</b> {} <br><b>Goal:</b> ${} <br> <b>BackerCount: </b> {}  </center>'.format(name, category, goal, count) for (name, count, goal, category) in popup_content]

len(popups)
# Out:
# 275048

# %%
m = folium.Map(location=[map_data.lat.mean(), map_data.lng.mean()], zoom_start=5)

marker_cluster = MarkerCluster(
    name='Global Kickstarter Campaigns',
    overlay=True,
    control=True,
    icon_create_function=None
)

for k in range(1000):
    location = locations[k][0], locations[k][1]
    marker = folium.Marker(location=location)
    popup = popups[k]
    folium.Popup(popup, max_width='150%').add_to(marker)
    if list(map_data.state)[k] == 'live':
        icons = folium.Icon(color='lightgreen', icon='bullhorn').add_to(marker)
    elif list(map_data.state)[k] == 'successful':
        icons = folium.Icon(color='green', icon='ok-sign').add_to(marker)
    else:
        icons = folium.Icon(color='red', icon='remove-sign').add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)
folium.LayerControl().add_to(m)

m.save(os.path.join('../../results', 'WorldKickStarterProjects_1000.html'))
